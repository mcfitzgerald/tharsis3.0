# %%
import sys
import copy
import emcee
import corner
import numpy as np
import matplotlib.pyplot as plt
from mods import prep, plotter
from scipy import optimize
# %matplotlib inline
# %load_ext autoreload

sys.path.append('./ligbind/')
import ligbind

# %%
def wymsol(var,parm,rtot,ltot):
    
    k11 = parm[0]
    k21 = parm[1]
    k22 = parm[2]
    l20 = parm[3]
    
    (L, M, MM, ML, MML, MMLL) = var
    
    eq1 = M + 2*MM + ML + 2*MML + 2*MMLL - rtot
    eq2 = L + ML + MML + 2*MMLL - ltot
    eq3 = l20 * M**2 - MM
    eq4 = k11 * L * M - ML
    eq5 = l20 * k21 * M**2 * L - MML
    eq6 = l20 * k21 * k22 * M**2 * L**2 - MMLL
    
    return np.array([eq1,eq2,eq3,eq4,eq5,eq6])

# %%
guess = (1000.,1000.,1000.,1000.,1000.,1000.)

# %%
parm4 = np.array([5.,5.,0.5,500.])

# %%
ligser = ligbind.helpers.dilser()

# %%
rtot1 = np.array([1e-4,1e-3,1e-2,1e-1,1e0])

# %%
def frax(res):
    L = res[:,0]
    M = res[:,1]
    MM = res[:,2]
    ML = res[:,3]
    MML = res[:,4]
    MMLL = res[:,5]
    
    Mfree = M + 2*MM
    
    Mtot = M + ML + 2*MM + 2*MML + 2*MMLL
    
    Ltot = L + ML + MML + 2*MMLL
    
    Mbound = ML + 2*MML + 2*MMLL
    
    Lbound = ML + MML + 2*MMLL
    
    Lfree_check = Ltot - Lbound
    
    Mfree_check = Mtot - Mbound
    
    Monomer = M + ML
    
    Dimer = 2*MM + 2*MML + 2*MMLL #quantified as monomer, i.e., [MM] = 2[M]
    
    Monfrac = Monomer/Mtot
    
    Dimfrac = Dimer/Mtot
    
    Mon_bfrac = ML/Monomer
    
    Dim_bfrac = (MML + 2*MMLL)/Dimer
    
    Bfrac = Lbound/Mtot
    
    
    return np.array([L,M,MM,ML,MML,MMLL,Bfrac,Monfrac,Dimfrac,Mon_bfrac,Dim_bfrac,Mtot])

# %%
colnames = ['L','M','MM','ML','MML','MMLL','Bfrac','Monfrac','Dimfrac','Mon_bfrac','Dim_bfrac','Mtot']

# %%
wymsol(guess,parm4,rtot1[0],ligser[0])
# Out:
# array([  7.99999990e+03,   4.99999900e+03,   4.99999000e+08,
#          4.99900000e+06,   2.50000000e+12,   1.25000000e+15])

# %%
res_mult = np.array([[optimize.root(wymsol,guess,args=(parm4,j,i),method='lm',options={'factor':0.1}).x for i in ligser] for j in rtot1])

# %%
fraxres = [frax(i) for i in res_mult]

# %%
#ind = 8
for i,j in enumerate(fraxres):
    plt.semilogy((j[ind]),'.',label=rtot1[i])
    #plt.legend()
    plt.title(colnames[ind])

# %%
parm5 = np.array([5.3,5.2,0.37,502.])

# %%
res_mult5 = np.array([[optimize.root(wymsol,guess,args=(parm5,j,i),method='lm',options={'factor':0.1}).x for i in ligser] for j in rtot1])

# %%
fraxres5 = [frax(i) for i in res_mult5]

# %%
ind = 8
for i,j in enumerate(fraxres5):
    plt.semilogy((j[ind]),'.',label=rtot1[i])
    plt.legend()
    plt.title(colnames[ind])

# %%
res_mult5[0][:,1]
# Out:
# array([  9.11350518e-05,   9.06947669e-05,   8.98268165e-05,
#          8.81397396e-05,   8.49485455e-05,   7.92117531e-05,
#          6.97840099e-05,   5.63629235e-05,   4.07016638e-05,
#          2.61599192e-05,   1.52566298e-05,   8.32041131e-06,
#          4.35785251e-06,   2.23193822e-06,   1.12971078e-06,
#          5.68354535e-07,   2.85060190e-07,   1.42751857e-07])

# %%
ind = 6
for i,j in enumerate(fraxres5):
    plt.semilogx(ligser,(j[ind]),'.',label=rtot1[i])
    plt.legend()
    plt.title(colnames[ind])

# %%
fraxres5[1][1]
# Out:
# array([  6.15021979e-04,   6.12710505e-04,   6.08142305e-04,
#          5.99218723e-04,   5.82176384e-04,   5.50981139e-04,
#          4.98037265e-04,   4.18590300e-04,   3.18570180e-04,
#          2.16666449e-04,   1.32736528e-04,   7.49982210e-05,
#          4.01551670e-05,   2.08235058e-05,   1.06101655e-05,
#          5.35630432e-06,   2.69116860e-06,   1.34886536e-06])

# %%
def dimfun(rtot,l20):
    k = 1/l20
    a = 4.
    b = -(4.*rtot + k)
    c = rtot**2
    rad = np.sqrt(b**2 - 4*a*c)
    
    D = (-b - rad)/(2*a)
    
    return D, 2*D/rtot

# %%
dimfun(0.001,100)
# Out:
# (7.2949016875157625e-05, 0.14589803375031524)

# %%
rtot1
# Out:
# array([  1.00000000e-04,   1.00000000e-03,   1.00000000e-02,
#          1.00000000e-01,   1.00000000e+00])

# %%
dimfun(rtot1,0.00001)[1]
# Out:
# array([  0.00000000e+00,   1.81898940e-08,   2.00088834e-07,
#          1.99997885e-06,   1.99992028e-05])

# %%
dimfun(rtot1,0.001)[1]
# Out:
# array([  2.00088834e-07,   2.00000727e-06,   1.99992002e-05,
#          1.99920040e-04,   1.99203978e-03])

# %%
ind = 8
for i,j in enumerate(fraxres):
    plt.semilogy((j[ind]),'.',label=rtot1[i])
    #plt.legend()
    plt.title(colnames[ind])

# %%
berbfun = dimfun(rtot1,500.)[1]

# %%
ind = 8
for i,j in enumerate(fraxres):
    plt.semilogx(ligser,(j[ind]),'.',label=rtot1[i])
    plt.axhline(berbfun[i])
    plt.legend()
    plt.title(colnames[ind])

# %%
ind = 8
for i,j in enumerate(fraxres5):
    plt.semilogx(ligser,(j[ind]),'.',label=rtot1[i])
    plt.axhline(berbfun[i])
    plt.legend()
    plt.title(colnames[ind])
plt.axvline(0.2)

# %%
parm6 = np.array([5.3,5.2,0.37,5000.])

# %%
def numsl(parms,rtot,ligser):
    #numerically solves wyman system of eqs for given rtots and ligand concs
    #solves against 100 randomly noise parm sets (noises +/- 5% of parm val)
    parmsets = [np.random.normal(1,0.05,4) * parms for i in range(100)]
    resset = [np.array([[optimize.root(wymsol,guess,args=(q,j,i),method='lm',options={'factor':0.1}).x for i in ligser] for j in rtot]) for q in parmsets]
    fraxset = [[frax(i) for i in j] for j in resset]
    
    return np.array(fraxset)

# %%
h = numsl(parm6,rtot1,ligser)

# %%
h.shape
# Out:
# (10, 5, 12, 18)

# %%
def slcmn(fraxset, ind):
    #computes mean solution
    #currently hardwired for rtot array of length 5
    slc = [np.array([i[j][ind] for i in fraxset]) for j in range(fraxset.shape[1])]
    mn = [i.mean(axis=0) for i in slc]
    
    return mn

# %%
slcmn(h,8)
# Out:
# [array([ 0.08740227,  0.08710311,  0.08651163,  0.08535529,  0.08314366,
#          0.07908523,  0.07217293,  0.06176673,  0.04867745,  0.03547242,
#          0.02480562,  0.01763508,  0.01339254,  0.01107025,  0.0098527 ,
#          0.00922981,  0.00889283,  0.00671907]),
#  array([ 0.39016312,  0.38946588,  0.38808163,  0.38535332,  0.38005166,
#          0.3700253 ,  0.35198713,  0.32220551,  0.27917047,  0.22725943,
#          0.1764734 ,  0.1360462 ,  0.10895575,  0.09290422,  0.08409973,
#          0.07947515,  0.07710933,  0.07587549]),
#  array([ 0.73525437,  0.73480877,  0.73392168,  0.73216373,  0.72871116,
#          0.72204737,  0.70959843,  0.68764454,  0.65235096,  0.60258753,
#          0.54305649,  0.48393355,  0.43538877,  0.40177096,  0.38133771,
#          0.36994532,  0.3639092 ,  0.36077026]),
#  array([ 0.90704528,  0.90690305,  0.90661897,  0.90605229,  0.90492517,
#          0.90269754,  0.89835888,  0.89018943,  0.87586456,  0.85364093,
#          0.82439988,  0.79250284,  0.76391816,  0.74266176,  0.72908525,
#          0.72128279,  0.7170782 ,  0.71489231]),
#  array([ 0.92828816,  0.92833994,  0.92814332,  0.92798507,  0.92757103,
#          0.92711676,  0.93029715,  0.95321969,  0.96053299,  0.95930806,
#          0.94873574,  0.93436134,  0.92076176,  0.91087614,  0.90483713,
#          0.90149853,  0.89974484,  0.89884648])]

# %%
def pltres(mn,rtotl,parms):
    for i in range(len(rtotl)):
        plt.plot(mn[i],'o',label=rtotl[i])
        plt.legend()
        plt.axhline((dimfun(rtotl,parms[-1])[1])[i])

# %%
pltres(slcmn(h,8),rtot1,parm6)

# %%
parm6
# Out:
# array([  5.30000000e+00,   5.20000000e+00,   3.70000000e-01,
#          5.00000000e+03])

# %%
def numsl_2(parms,rtot,ligser):
    #numerically solves wyman system of eqs for given rtots and ligand concs
    #solves against 10 randomly noise parm sets (noises +/- 5% of parm val)
    parmsets = [np.random.normal(1,0.05,4) * parms for i in range(10)]
    resset = [np.array([[optimize.root(wymsol,guess,args=(q,j,i),method='lm',options={'factor':0.1}).x for i in ligser] for j in rtot]) for q in parmsets]
    fraxset = [[frax(i) for i in j] for j in resset]
    
    return np.array(fraxset)

# %%
h = numsl_2(parm7,rtot1*2.41,ligser)

# %%
pltres(slcmn(h,8),rtot1*2.41,parm7)

# %%
parm7 = np.array([4.6,5.3,0.34,530.])

# %%
h = numsl_2(parm7,rtot1,ligser)

# %%
pltres(slcmn(h,8),rtot1,parm7)

# %%
rts = np.array([ 0.001 ,  0.0025,  0.005 ,  0.01  ,  0.025 ,  0.05  ])

# %%
plt.plot(dimfun(rts,10000)[1],'o')

# %%
wrdparm = np.array([  4.46042795,   5.54982900e+00,   8.88031378e-01,
         500.])

# %%
weirdsim = numsl_2(wrdparm,rts,ligser)

# %%
ind = 7
pltres(slcmn(weirdsim,ind),rts,wrdparm)
plt.title(colnames[ind])

# %%
wrdparm2 = np.array([  44.6042795,   5.54982900e+00,   8.88031378e-01,
         50000.])

# %%
weirdsim2 = numsl_2(wrdparm2,rts,ligser)

# %%
ind = 7
pltres(slcmn(weirdsim2,ind),rts,wrdparm2)
plt.title(colnames[ind])

# %%
for i,j in enumerate(colnames):
    print(i,j)
# Out:
# 0 L
# 1 M
# 2 MM
# 3 ML
# 4 MML
# 5 MMLL
# 6 Bfrac
# 7 Monfrac
# 8 Dimfrac
# 9 Mon_bfrac
# 10 Dim_bfrac
# 11 Mtot

# %%
parm7

# %%
parmwerd = np.array([  4.46042795e+01,   5.54982900e+00,   8.88031378e-01,
         5.79091318e+05])

# %%
parmwerd

# %%
hwerd = numsl_2(parm7,rtot,ligser)

# %%
del(rtot)
